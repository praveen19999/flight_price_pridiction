# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time

# %%
# lets first connect to web driver
driver = webdriver.Chrome(r'C:\Users\Praveen\chromdriver.web\chromedriver.exe')

# %%
url = 'https://www.makemytrip.com/'
driver.get(url)

# %%
search = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/div/div/div[2]/p/a')
search.click()

# %%
Date = driver.find_element(By.XPATH,'//div[@class="makeFlex spaceBtwCenter fontSize12 card-footer-v2"]')
Date.click()

# %%
flight_name = []
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name.append(i.text)
print(len(flight_name))

dept_time = []
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time.append(i.text)
print(len(dept_time))

arive_time =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time.append(i.text)
print(len(arive_time))

Source =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source.append(i.text)
print(len(Source))

Destination =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination.append(i.text)
print(len(Destination))

Duration =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration.append(i.text)
print(len(Duration))

Price =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price.append(i.text)
print(len(Price))

df0 = pd.DataFrame()
df0['Flight'] = flight_name
df0['DepartureTime'] = dept_time
df0['ArivalTime']=arive_time
df0['source']=Source
df0['Destination']=Destination
df0['Duration']=Duration
df0['Price_']=Price
df0['Date']='8/1/2023'
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50

# %%
df0.head()
# Out:
#      Flight DepartureTime ArivalTime     source Destination  \
# 0  SpiceJet         06:20      09:10  New Delhi   Bengaluru
# 1   AirAsia         08:10      10:55  New Delhi   Bengaluru
# 2    IndiGo         07:55      10:55  New Delhi   Bengaluru
# 3    IndiGo         04:20      07:15  New Delhi   Bengaluru
# 4    IndiGo         05:55      08:45  New Delhi   Bengaluru
#
#               Duration   Price_      Date
# 0  02 h 50 m\nNon stop  ₹ 5,234  8/1/2023
# 1  02 h 45 m\nNon stop  ₹ 5,235  8/1/2023
# 2       03 h\nNon stop  ₹ 4,537  8/1/2023
# 3  02 h 55 m\nNon stop  ₹ 5,237  8/1/2023
# 4  02 h 50 m\nNon stop  ₹ 5,237  8/1/2023

# %%
Date1 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-2"]')
Date1.click()

# %%
flight_name1 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name1.append(i.text)
print(len(flight_name1))

dept_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time1.append(i.text)
print(len(dept_time1))

arive_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time1.append(i.text)
print(len(arive_time1))

Source1 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source1.append(i.text)
print(len(Source1))

Destination1 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination1.append(i.text)
print(len(Destination1))

Duration1 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration1.append(i.text)
print(len(Duration1))

Price1 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price1.append(i.text)
print(len(Price1))

df1 = pd.DataFrame()
df1['Flight'] = flight_name1
df1['DepartureTime'] = dept_time1
df1['ArivalTime']=arive_time1
df1['source']=Source1
df1['Destination']=Destination1
df1['Duration']=Duration1
df1['Price_']=Price1
df1['Date']='9/1/2023'
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50

# %%
Date2 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-1"]')
Date2.click()

# %%
flight_name2 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name2.append(i.text)
print(len(flight_name2))

dept_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time2.append(i.text)
print(len(dept_time2))

arive_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time2.append(i.text)
print(len(arive_time2))

Source2 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source2.append(i.text)
print(len(Source2))

Destination2 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination2.append(i.text)
print(len(Destination2))

Duration2 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration2.append(i.text)
print(len(Duration2))

Price2 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price2.append(i.text)
print(len(Price2))

df2 = pd.DataFrame()
df2['Flight'] = flight_name2
df2['DepartureTime'] = dept_time2
df2['ArivalTime']=arive_time2
df2['source']=Source2
df2['Destination']=Destination2
df2['Duration']=Duration2
df2['Price_']=Price2
df2['Date']='10/1/2023'
# Out:
# 49
# 49
# 49
# 49
# 49
# 49
# 49

# %%
Date3 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"][1]')
Date3.click()

# %%
flight_name3 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name3.append(i.text)
print(len(flight_name3))

dept_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time3.append(i.text)
print(len(dept_time3))

arive_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time3.append(i.text)
print(len(arive_time3))

Source3 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source3.append(i.text)
print(len(Source3))

Destination3 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination3.append(i.text)
print(len(Destination3))

Duration3 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration3.append(i.text)
print(len(Duration3))

Price3 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price3.append(i.text)
print(len(Price3))

df3 = pd.DataFrame()
df3['Flight'] = flight_name3
df3['DepartureTime'] = dept_time3
df3['ArivalTime']=arive_time3
df3['source']=Source3
df3['Destination']=Destination3
df3['Duration']=Duration3
df3['Price_']=Price3
df3['Date']='11/1/2023'
# Out:
# 46
# 46
# 46
# 46
# 46
# 46
# 46

# %%
Date4 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"]')
Date4.click()

# %%
flight_name4 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name4.append(i.text)
print(len(flight_name4))

dept_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time4.append(i.text)
print(len(dept_time4))

arive_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time4.append(i.text)
print(len(arive_time4))

Source4 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source4.append(i.text)
print(len(Source4))

Destination4 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination4.append(i.text)
print(len(Destination4))

Duration4 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration4.append(i.text)
print(len(Duration4))

Price4 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price4.append(i.text)
print(len(Price4))

df4 = pd.DataFrame()
df4['Flight'] = flight_name4
df4['DepartureTime'] = dept_time4
df4['ArivalTime']=arive_time4
df4['source']=Source4
df4['Destination']=Destination4
df4['Duration']=Duration4
df4['Price_']=Price4
df4['Date']='12/1/2023'
# Out:
# 46
# 46
# 46
# 46
# 46
# 46
# 46

# %%
Date5 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-1"]')
Date5.click()

# %%
flight_name5 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name5.append(i.text)
print(len(flight_name5))

dept_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time5.append(i.text)
print(len(dept_time5))

arive_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time5.append(i.text)
print(len(arive_time5))

Source5 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source5.append(i.text)
print(len(Source5))

Destination5 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination5.append(i.text)
print(len(Destination5))

Duration5 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration5.append(i.text)
print(len(Duration5))

Price5 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price5.append(i.text)
print(len(Price5))

df5 = pd.DataFrame()
df5['Flight'] = flight_name5
df5['DepartureTime'] = dept_time5
df5['ArivalTime']=arive_time5
df5['source']=Source5
df5['Destination']=Destination5
df5['Duration']=Duration5
df5['Price_']=Price5
df5['Date']='13/1/2023'
# Out:
# 46
# 46
# 46
# 46
# 46
# 46
# 46

# %%
Date6 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-2"]')
Date6.click()

# %%
flight_name6 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name6.append(i.text)
print(len(flight_name6))

dept_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time6.append(i.text)
print(len(dept_time6))

arive_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time6.append(i.text)
print(len(arive_time6))

Source6 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source6.append(i.text)
print(len(Source6))

Destination6 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination6.append(i.text)
print(len(Destination6))

Duration6 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration6.append(i.text)
print(len(Duration6))

Price6 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price6.append(i.text)
print(len(Price6))

df6 = pd.DataFrame()
df6['Flight'] = flight_name6
df6['DepartureTime'] = dept_time6
df6['ArivalTime']=arive_time6
df6['source']=Source6
df6['Destination']=Destination6
df6['Duration']=Duration6
df6['Price_']=Price6
df6['Date']='14/1/2023'
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50

# %%
click_next = driver.find_element(By.XPATH,'//button[@class="glider-next"][1]')
click_next.click()

# %%
Date7 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide active visible left-4"]')
Date7.click()

# %%
flight_name7 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name7.append(i.text)
print(len(flight_name7))

dept_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time7.append(i.text)
print(len(dept_time7))

arive_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time7.append(i.text)
print(len(arive_time7))

Source7 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source7.append(i.text)
print(len(Source7))

Destination7 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination7.append(i.text)
print(len(Destination7))

Duration7 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration7.append(i.text)
print(len(Duration7))

Price7 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price7.append(i.text)
print(len(Price7))

df7 = pd.DataFrame()
df7['Flight'] = flight_name7
df7['DepartureTime'] = dept_time7
df7['ArivalTime']=arive_time7
df7['source']=Source7
df7['Destination']=Destination7
df7['Duration']=Duration7
df7['Price_']=Price7
df7['Date']='15/1/2023'
# Out:
# 46
# 46
# 46
# 46
# 46
# 46
# 46

# %%
Data1 = pd.concat([df0,df1,df2,df3,df4,df5,df6,df7],axis = 0)

# %%
Data1.head()
# Out:
#      Flight DepartureTime ArivalTime     source Destination  \
# 0  SpiceJet         06:20      09:10  New Delhi   Bengaluru
# 1   AirAsia         08:10      10:55  New Delhi   Bengaluru
# 2    IndiGo         07:55      10:55  New Delhi   Bengaluru
# 3    IndiGo         04:20      07:15  New Delhi   Bengaluru
# 4    IndiGo         05:55      08:45  New Delhi   Bengaluru
#
#               Duration   Price_      Date
# 0  02 h 50 m\nNon stop  ₹ 5,234  8/1/2023
# 1  02 h 45 m\nNon stop  ₹ 5,235  8/1/2023
# 2       03 h\nNon stop  ₹ 4,537  8/1/2023
# 3  02 h 55 m\nNon stop  ₹ 5,237  8/1/2023
# 4  02 h 50 m\nNon stop  ₹ 5,237  8/1/2023

# %%
search_flight = driver.find_element(By.XPATH,'//div[@class="hsw_inputBox width160"][2]/input')
search_flight.send_keys("Chennai")

# %%
First_click = driver.find_element(By.XPATH,'//li[@class="react-autosuggest__suggestion react-autosuggest__suggestion--first"]')
First_click.click()

# %%
date_click = driver.find_element(By.XPATH,'//div[@class="DayPicker-Day"][1]')
date_click.click()

# %%
search = driver.find_element(By.XPATH,'//button[@class="primaryBtn hsw_searchButton"]')
search.click()

# %%
flight_name1 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name1.append(i.text)
print(len(flight_name1))

dept_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time1.append(i.text)
print(len(dept_time1))

arive_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time1.append(i.text)
print(len(arive_time1))

Source1 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source1.append(i.text)
print(len(Source1))

Duration1 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration1.append(i.text)
print(len(Duration1))

Price1 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price1.append(i.text)
print(len(Price1))

df1 = pd.DataFrame()
df1['Flight'] = flight_name1
df1['DepartureTime'] = dept_time1
df1['ArivalTime']=arive_time1
df1['source']=Source1
df1['Destination']='Chennai'
df1['Duration']=Duration1
df1['Price_']=Price1
df1['Date']='8/1/2023'
# Out:
# 28
# 28
# 28
# 28
# 28
# 28

# %%
Date = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-2"]')
Date.click()

# %%
flight_name2 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name2.append(i.text)
print(len(flight_name2))

dept_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time2.append(i.text)
print(len(dept_time2))

arive_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time2.append(i.text)
print(len(arive_time2))

Source2 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source2.append(i.text)
print(len(Source2))


Duration2 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration2.append(i.text)
print(len(Duration2))

Price2 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price2.append(i.text)
print(len(Price2))

df2 = pd.DataFrame()
df2['Flight'] = flight_name2
df2['DepartureTime'] = dept_time2
df2['ArivalTime']=arive_time2
df2['source']=Source2
df2['Destination']='Chennai'
df2['Duration']=Duration2
df2['Price_']=Price2
df2['Date']='9/1/2023'
# Out:
# 31
# 31
# 31
# 31
# 31
# 31

# %%
Date = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-1"]')
Date.click()

# %%
flight_name3 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name3.append(i.text)
print(len(flight_name3))

dept_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time3.append(i.text)
print(len(dept_time3))

arive_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time3.append(i.text)
print(len(arive_time3))

Source3 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source3.append(i.text)
print(len(Source3))

Duration3 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration3.append(i.text)
print(len(Duration3))

Price3 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price3.append(i.text)
print(len(Price3))

df3 = pd.DataFrame()
df3['Flight'] = flight_name3
df3['DepartureTime'] = dept_time3
df3['ArivalTime']=arive_time3
df3['source']=Source3
df3['Destination']='Chennai'
df3['Duration']=Duration3
df3['Price_']=Price3
df3['Date']='10/1/2023'
# Out:
# 28
# 28
# 28
# 28
# 28
# 28
# 28

# %%
Date3 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"][1]')
Date3.click()

# %%
flight_name4 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name4.append(i.text)
print(len(flight_name4))

dept_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time4.append(i.text)
print(len(dept_time4))

arive_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time4.append(i.text)
print(len(arive_time4))

Source4 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source4.append(i.text)
print(len(Source4))

Duration4 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration4.append(i.text)
print(len(Duration4))

Price4 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price4.append(i.text)
print(len(Price4))

df4 = pd.DataFrame()
df4['Flight'] = flight_name4
df4['DepartureTime'] = dept_time4
df4['ArivalTime']=arive_time4
df4['source']=Source4
df4['Destination']='Chennai'
df4['Duration']=Duration4
df4['Price_']=Price4
df4['Date']='11/1/2023'
# Out:
# 28
# 28
# 28
# 28
# 28
# 28

# %%
Date5 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"][1]')
Date5.click()

# %%
flight_name5 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name5.append(i.text)
print(len(flight_name5))

dept_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time5.append(i.text)
print(len(dept_time5))

arive_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time5.append(i.text)
print(len(arive_time5))

Source5 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source5.append(i.text)
print(len(Source5))

Duration5 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration5.append(i.text)
print(len(Duration5))

Price5 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price5.append(i.text)
print(len(Price5))

df5 = pd.DataFrame()
df5['Flight'] = flight_name5
df5['DepartureTime'] = dept_time5
df5['ArivalTime']=arive_time5
df5['source']=Source5
df5['Destination']='Chennai'
df5['Duration']=Duration5
df5['Price_']=Price5
df5['Date']='12/1/2023'
# Out:
# 28
# 28
# 28
# 28
# 28
# 28

# %%
Date6 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-1"]')
Date6.click()

# %%
flight_name6 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name6.append(i.text)
print(len(flight_name6))

dept_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time6.append(i.text)
print(len(dept_time6))

arive_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time6.append(i.text)
print(len(arive_time6))

Source6 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source6.append(i.text)
print(len(Source6))

Duration6 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration6.append(i.text)
print(len(Duration6))

Price6 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price6.append(i.text)
print(len(Price6))

df6 = pd.DataFrame()
df6['Flight'] = flight_name6
df6['DepartureTime'] = dept_time6
df6['ArivalTime']=arive_time6
df6['source']=Source6
df6['Destination']='Chennai'
df6['Duration']=Duration6
df6['Price_']=Price6
df6['Date']='13/1/2023'
# Out:
# 27
# 27
# 27
# 27
# 27
# 27

# %%
Date7 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-2"]')
Date7.click()

# %%
flight_name7 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name7.append(i.text)
print(len(flight_name7))

dept_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time7.append(i.text)
print(len(dept_time7))

arive_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time7.append(i.text)
print(len(arive_time7))

Source7 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source7.append(i.text)
print(len(Source7))


Duration7 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration7.append(i.text)
print(len(Duration7))

Price7=[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price7.append(i.text)
print(len(Price7))

df7 = pd.DataFrame()
df7['Flight'] = flight_name7
df7['DepartureTime'] = dept_time7
df7['ArivalTime']=arive_time7
df7['source']=Source7
df7['Destination']='Chennai'
df7['Duration']=Duration7
df7['Price_']=Price7
df7['Date']='14/1/2023'
# Out:
# 32
# 32
# 32
# 32
# 32
# 32

# %%
button = driver.find_element(By.XPATH,'//button[@class="glider-next"][1]')
button.click()

# %%
Date8 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide active visible left-4"]')
Date8.click()

# %%
flight_name8 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name8.append(i.text)
print(len(flight_name8))

dept_time8 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time8.append(i.text)
print(len(dept_time8))

arive_time8 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time8.append(i.text)
print(len(arive_time8))

Source8 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source8.append(i.text)
print(len(Source8))

Duration8 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration8.append(i.text)
print(len(Duration8))

Price8=[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price8.append(i.text)
print(len(Price8))

df8 = pd.DataFrame()
df8['Flight'] = flight_name8
df8['DepartureTime'] = dept_time8
df8['ArivalTime']=arive_time8
df8['source']=Source8
df8['Destination']='Chennai'
df8['Duration']=Duration8
df8['Price_']=Price8
df8['Date']='15/1/2023'
# Out:
# 30
# 30
# 30
# 30
# 30
# 30

# %%
Data2 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8],axis = 0)

# %%
Data2
# Out:
#        Flight DepartureTime      ArivalTime     source Destination  \
# 0      IndiGo         07:55           17:35  New Delhi     Chennai
# 1    SpiceJet         18:50           21:30  New Delhi     Chennai
# 2     AirAsia         09:30           17:05  New Delhi     Chennai
# 3      IndiGo         07:10           10:05  New Delhi     Chennai
# 4      IndiGo         08:25           11:20  New Delhi     Chennai
# ..        ...           ...             ...        ...         ...
# 25     IndiGo         01:55           07:05  New Delhi     Chennai
# 26     IndiGo         17:15           22:45  New Delhi     Chennai
# 27  Air India         09:45           12:35  New Delhi     Chennai
# 28  Air India         20:00  01:05\n+ 1 DAY  New Delhi     Chennai
# 29  Air India         11:50           14:45  New Delhi     Chennai
#
#                            Duration    Price_       Date
# 0   09 h 40 m\n1 stop via Bengaluru   ₹ 6,310   8/1/2023
# ...

# %%
search_flight = driver.find_element(By.XPATH,'//div[@class="hsw_inputBox width160"][2]/input')
search_flight.send_keys("Kolkata")

# %%
First_click = driver.find_element(By.XPATH,'//li[@class="react-autosuggest__suggestion react-autosuggest__suggestion--first"]')
First_click.click()

# %%
date_click = driver.find_element(By.XPATH,'//div[@class="DayPicker-Day"][1]')
date_click.click()

# %%
search = driver.find_element(By.XPATH,'//button[@class="primaryBtn hsw_searchButton"]')
search.click()

# %%
flight_name1 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name1.append(i.text)
print(len(flight_name1))

dept_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time1.append(i.text)
print(len(dept_time1))

arive_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time1.append(i.text)
print(len(arive_time1))

Source1 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source1.append(i.text)
print(len(Source1))

Destination1 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination1.append(i.text)
print(len(Destination1))

Duration1 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration1.append(i.text)
print(len(Duration1))

Price1 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price1.append(i.text)
print(len(Price1))

df1 = pd.DataFrame()
df1['Flight'] = flight_name1
df1['DepartureTime'] = dept_time1
df1['ArivalTime']=arive_time1
df1['source']=Source1
df1['Destination']=Destination1
df1['Duration']=Duration1
df1['Price_']=Price1
df1['Date']='8/1/2023'
# Out:
# 31
# 31
# 31
# 31
# 31
# 31
# 31

# %%
Date = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-2"]')
Date.click()

# %%
flight_name2 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name2.append(i.text)
print(len(flight_name2))

dept_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time2.append(i.text)
print(len(dept_time2))

arive_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time2.append(i.text)
print(len(arive_time2))

Source2 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source2.append(i.text)
print(len(Source2))

Destination2 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination2.append(i.text)
print(len(Destination2))

Duration2 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration2.append(i.text)
print(len(Duration2))

Price2 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price2.append(i.text)
print(len(Price2))

df2 = pd.DataFrame()
df2['Flight'] = flight_name2
df2['DepartureTime'] = dept_time2
df2['ArivalTime']=arive_time2
df2['source']=Source2
df2['Destination']=Destination2
df2['Duration']=Duration2
df2['Price_']=Price2
df2['Date']='9/1/2023'
# Out:
# 32
# 32
# 32
# 32
# 32
# 32
# 32

# %%
Date = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-1"]')
Date.click()

# %%
flight_name3 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name3.append(i.text)
print(len(flight_name3))

dept_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time3.append(i.text)
print(len(dept_time3))

arive_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time3.append(i.text)
print(len(arive_time3))

Source3 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source3.append(i.text)
print(len(Source3))

Destination3 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination3.append(i.text)
print(len(Destination3))

Duration3 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration3.append(i.text)
print(len(Duration3))

Price3 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price3.append(i.text)
print(len(Price3))

df3 = pd.DataFrame()
df3['Flight'] = flight_name3
df3['DepartureTime'] = dept_time3
df3['ArivalTime']=arive_time3
df3['source']=Source3
df3['Destination']=Destination3
df3['Duration']=Duration3
df3['Price_']=Price3
df3['Date']='10/1/2023'
# Out:
# 33
# 33
# 33
# 33
# 33
# 33
# 33

# %%
Date3 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"][1]')
Date3.click()

# %%
flight_name4 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name4.append(i.text)
print(len(flight_name4))

dept_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time4.append(i.text)
print(len(dept_time4))

arive_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time4.append(i.text)
print(len(arive_time4))

Source4 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source4.append(i.text)
print(len(Source4))

Destination4 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination4.append(i.text)
print(len(Destination4))

Duration4 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration4.append(i.text)
print(len(Duration4))

Price4 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price4.append(i.text)
print(len(Price4))

df4 = pd.DataFrame()
df4['Flight'] = flight_name4
df4['DepartureTime'] = dept_time4
df4['ArivalTime']=arive_time4
df4['source']=Source4
df4['Destination']=Destination4
df4['Duration']=Duration4
df4['Price_']=Price4
df4['Date']='11/1/2023'
# Out:
# 33
# 33
# 33
# 33
# 33
# 33
# 33

# %%
Date5 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"]')
Date5.click()

# %%
flight_name5 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name5.append(i.text)
print(len(flight_name5))

dept_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time5.append(i.text)
print(len(dept_time5))

arive_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time5.append(i.text)
print(len(arive_time5))

Source5 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source5.append(i.text)
print(len(Source5))

Destination5 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination5.append(i.text)
print(len(Destination5))

Duration5 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration5.append(i.text)
print(len(Duration5))

Price5 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price5.append(i.text)
print(len(Price5))

df5 = pd.DataFrame()
df5['Flight'] = flight_name5
df5['DepartureTime'] = dept_time5
df5['ArivalTime']=arive_time5
df5['source']=Source5
df5['Destination']=Destination5
df5['Duration']=Duration5
df5['Price_']=Price5
df5['Date']='12/1/2023'
# Out:
# 36
# 36
# 36
# 36
# 36
# 36
# 36

# %%
Date6 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-1"]')
Date6.click()

# %%
flight_name6 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name6.append(i.text)
print(len(flight_name6))

dept_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time6.append(i.text)
print(len(dept_time6))

arive_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time6.append(i.text)
print(len(arive_time6))

Source6 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source6.append(i.text)
print(len(Source6))

Destination6 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination6.append(i.text)
print(len(Destination6))

Duration6 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration6.append(i.text)
print(len(Duration6))

Price6 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price6.append(i.text)
print(len(Price6))

df6 = pd.DataFrame()
df6['Flight'] = flight_name6
df6['DepartureTime'] = dept_time6
df6['ArivalTime']=arive_time6
df6['source']=Source6
df6['Destination']=Destination6
df6['Duration']=Duration6
df6['Price_']=Price6
df6['Date']='13/1/2023'
# Out:
# 30
# 30
# 30
# 30
# 30
# 30
# 30

# %%
Date7 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-2"]')
Date7.click()

# %%
flight_name7 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name7.append(i.text)
print(len(flight_name7))

dept_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time7.append(i.text)
print(len(dept_time7))

arive_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time7.append(i.text)
print(len(arive_time7))

Source7 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source7.append(i.text)
print(len(Source7))

Destination7 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination7.append(i.text)
print(len(Destination7))

Duration7 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration7.append(i.text)
print(len(Duration7))

Price7=[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price7.append(i.text)
print(len(Price7))

df7 = pd.DataFrame()
df7['Flight'] = flight_name7
df7['DepartureTime'] = dept_time7
df7['ArivalTime']=arive_time7
df7['source']=Source7
df7['Destination']=Destination7
df7['Duration']=Duration7
df7['Price_']=Price7
df7['Date']='14/1/2023'
# Out:
# 31
# 31
# 31
# 31
# 31
# 31
# 31

# %%
button = driver.find_element(By.XPATH,'//button[@class="glider-next"][1]')
button.click()

# %%
Date8 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide active visible left-4"]')
Date8.click()

# %%
flight_name8 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name8.append(i.text)
print(len(flight_name8))

dept_time8 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time8.append(i.text)
print(len(dept_time8))

arive_time8 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time8.append(i.text)
print(len(arive_time8))

Source8 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source8.append(i.text)
print(len(Source8))

Destination8 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination8.append(i.text)
print(len(Destination8))

Duration8 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration8.append(i.text)
print(len(Duration8))

Price8=[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price8.append(i.text)
print(len(Price8))

df8 = pd.DataFrame()
df8['Flight'] = flight_name8
df8['DepartureTime'] = dept_time8
df8['ArivalTime']=arive_time8
df8['source']=Source8
df8['Destination']=Destination8
df8['Duration']=Duration8
df8['Price_']=Price8
df8['Date']='15/1/2023'
# Out:
# 29
# 29
# 29
# 29
# 29
# 29
# 29

# %%
Data3 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8],axis = 0)

# %%
Data3
# Out:
#        Flight DepartureTime      ArivalTime     source Destination  \
# 0    SpiceJet         08:30  10:25\n+ 1 DAY  New Delhi     Kolkata
# 1    SpiceJet         05:45           07:45  New Delhi     Kolkata
# 2      IndiGo         05:35           10:50  New Delhi     Kolkata
# 3     Vistara         06:30           08:20  New Delhi     Kolkata
# 4    Go First         21:00  10:00\n+ 1 DAY  New Delhi     Kolkata
# ..        ...           ...             ...        ...         ...
# 24     IndiGo         10:10           17:15  New Delhi     Kolkata
# 25     IndiGo         10:00           12:10  New Delhi     Kolkata
# 26     IndiGo         13:55           18:45  New Delhi     Kolkata
# 27     IndiGo         09:00           11:10  New Delhi     Kolkata
# 28  Air India         09:25           15:30  New Delhi     Kolkata
#
#                            Duration    Price_       Date
# 0    25 h 55 m\n1 stop via Bagdogra   ₹ 6,771   8/1/2023
# ...

# %%
search_flight = driver.find_element(By.XPATH,'//div[@class="hsw_inputBox width160"][2]/input')
search_flight.send_keys("Mumbai")

# %%
First_click = driver.find_element(By.XPATH,'//li[@class="react-autosuggest__suggestion react-autosuggest__suggestion--first"]')
First_click.click()

# %%
date_click = driver.find_element(By.XPATH,'//div[@class="DayPicker-Day"][1]')
date_click.click()

# %%
search = driver.find_element(By.XPATH,'//button[@class="primaryBtn hsw_searchButton"]')
search.click()

# %%
flight_name1 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name1.append(i.text)
print(len(flight_name1))

dept_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:117:2]:
    dept_time1.append(i.text)
print(len(dept_time1))

arive_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:117:2]:
    arive_time1.append(i.text)
print(len(arive_time1))

Source1 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:117:2]:
    Source1.append(i.text)
print(len(Source1))

Destination1 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:117:2]:
    Destination1.append(i.text)
print(len(Destination1))

Duration1 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration1.append(i.text)
print(len(Duration1))

Price1 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price1.append(i.text)
print(len(Price1))

df1 = pd.DataFrame()
df1['Flight'] = flight_name1
df1['DepartureTime'] = dept_time1
df1['ArivalTime']=arive_time1
df1['source']=Source1
df1['Destination']=Destination1
df1['Duration']=Duration1
df1['Price_']=Price1
df1['Date']='8/1/2023'
# Out:
# 57
# 57
# 57
# 57
# 57
# 57
# 57

# %%
Date = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-2"]')
Date.click()

# %%
flight_name2 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name2.append(i.text)
print(len(flight_name2))

dept_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:200:2]:
    dept_time2.append(i.text)
print(len(dept_time2))

arive_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:200:2]:
    arive_time2.append(i.text)
print(len(arive_time2))

Source2 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:200:2]:
    Source2.append(i.text)
print(len(Source2))

Destination2 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:200:2]:
    Destination2.append(i.text)
print(len(Destination2))

Duration2 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration2.append(i.text)
print(len(Duration2))

Price2 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price2.append(i.text)
print(len(Price2))

df2 = pd.DataFrame()
df2['Flight'] = flight_name2
df2['DepartureTime'] = dept_time2
df2['ArivalTime']=arive_time2
df2['source']=Source2
df2['Destination']=Destination2
df2['Duration']=Duration2
df2['Price_']=Price2
df2['Date']='9/1/2023'
# Out:
# 75
# 75
# 75
# 75
# 75
# 75
# 75

# %%
Date = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-1"]')
Date.click()

# %%
flight_name3 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name3.append(i.text)
print(len(flight_name3))

dept_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:200:2]:
    dept_time3.append(i.text)
print(len(dept_time3))

arive_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:200:2]:
    arive_time3.append(i.text)
print(len(arive_time3))

Source3 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:200:2]:
    Source3.append(i.text)
print(len(Source3))

Destination3 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:200:2]:
    Destination3.append(i.text)
print(len(Destination3))

Duration3 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration3.append(i.text)
print(len(Duration3))

Price3 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price3.append(i.text)
print(len(Price3))

df3 = pd.DataFrame()
df3['Flight'] = flight_name3
df3['DepartureTime'] = dept_time3
df3['ArivalTime']=arive_time3
df3['source']=Source3
df3['Destination']=Destination3
df3['Duration']=Duration3
df3['Price_']=Price3
df3['Date']='10/1/2023'
# Out:
# 63
# 63
# 63
# 63
# 63
# 63
# 63

# %%
Date4 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"][1]')
Date4.click()

# %%
flight_name4 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name4.append(i.text)
print(len(flight_name4))

dept_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:200:2]:
    dept_time4.append(i.text)
print(len(dept_time4))

arive_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:200:2]:
    arive_time4.append(i.text)
print(len(arive_time4))

Source4 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:200:2]:
    Source4.append(i.text)
print(len(Source4))

Destination4 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:200:2]:
    Destination4.append(i.text)
print(len(Destination4))

Duration4 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration4.append(i.text)
print(len(Duration4))

Price4 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price4.append(i.text)
print(len(Price4))

df4 = pd.DataFrame()
df4['Flight'] = flight_name4
df4['DepartureTime'] = dept_time4
df4['ArivalTime']=arive_time4
df4['source']=Source4
df4['Destination']=Destination4
df4['Duration']=Duration4
df4['Price_']=Price4
df4['Date']='11/1/2023'
# Out:
# 63
# 63
# 63
# 63
# 63
# 63
# 63

# %%
Date5 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"]')
Date5.click()

# %%
flight_name5 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name5.append(i.text)
print(len(flight_name5))

dept_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:200:2]:
    dept_time5.append(i.text)
print(len(dept_time5))

arive_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:200:2]:
    arive_time5.append(i.text)
print(len(arive_time5))

Source5 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:200:2]:
    Source5.append(i.text)
print(len(Source5))

Destination5 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:200:2]:
    Destination5.append(i.text)
print(len(Destination5))

Duration5 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration5.append(i.text)
print(len(Duration5))

Price5 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price5.append(i.text)
print(len(Price5))

df5 = pd.DataFrame()
df5['Flight'] = flight_name5
df5['DepartureTime'] = dept_time5
df5['ArivalTime']=arive_time5
df5['source']=Source5
df5['Destination']=Destination5
df5['Duration']=Duration5
df5['Price_']=Price5
df5['Date']='12/1/2023'
# Out:
# 65
# 65
# 65
# 65
# 65
# 65
# 65

# %%
Date6 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-1"]')
Date6.click()

# %%
flight_name6 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name6.append(i.text)
print(len(flight_name6))

dept_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:200:2]:
    dept_time6.append(i.text)
print(len(dept_time6))

arive_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:200:2]:
    arive_time6.append(i.text)
print(len(arive_time6))

Source6 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:200:2]:
    Source6.append(i.text)
print(len(Source6))

Destination6 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:200:2]:
    Destination6.append(i.text)
print(len(Destination6))

Duration6 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration6.append(i.text)
print(len(Duration6))

Price6 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price6.append(i.text)
print(len(Price6))

df6 = pd.DataFrame()
df6['Flight'] = flight_name6
df6['DepartureTime'] = dept_time6
df6['ArivalTime']=arive_time6
df6['source']=Source6
df6['Destination']=Destination6
df6['Duration']=Duration6
df6['Price_']=Price6
df6['Date']='13/1/2023'
# Out:
# 62
# 62
# 62
# 62
# 62
# 62
# 62

# %%
Date7 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-2"]')
Date7.click()

# %%
flight_name7 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name7.append(i.text)
print(len(flight_name7))

dept_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:200:2]:
    dept_time7.append(i.text)
print(len(dept_time7))

arive_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:200:2]:
    arive_time7.append(i.text)
print(len(arive_time7))

Source7 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:200:2]:
    Source7.append(i.text)
print(len(Source7))

Destination7 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:200:2]:
    Destination7.append(i.text)
print(len(Destination7))

Duration7 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration7.append(i.text)
print(len(Duration7))

Price7=[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price7.append(i.text)
print(len(Price7))

df7 = pd.DataFrame()
df7['Flight'] = flight_name7
df7['DepartureTime'] = dept_time7
df7['ArivalTime']=arive_time7
df7['source']=Source7
df7['Destination']=Destination7
df7['Duration']=Duration7
df7['Price_']=Price7
df7['Date']='14/1/2023'
# Out:
# 62
# 62
# 62
# 62
# 62
# 62
# 62

# %%
button = driver.find_element(By.XPATH,'//button[@class="glider-next"][1]')
button.click()

# %%
Date8 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide active visible left-4"]')
Date8.click()

# %%
flight_name8 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name8.append(i.text)
print(len(flight_name8))

dept_time8 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:117:2]:
    dept_time8.append(i.text)
print(len(dept_time8))

arive_time8 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:117:2]:
    arive_time8.append(i.text)
print(len(arive_time8))

Source8 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:117:2]:
    Source8.append(i.text)
print(len(Source8))

Destination8 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:117:2]:
    Destination8.append(i.text)
print(len(Destination8))

Duration8 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration8.append(i.text)
print(len(Duration8))

Price8=[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price8.append(i.text)
print(len(Price8))

df8 = pd.DataFrame()
df8['Flight'] = flight_name8
df8['DepartureTime'] = dept_time8
df8['ArivalTime']=arive_time8
df8['source']=Source8
df8['Destination']=Destination8
df8['Duration']=Duration8
df8['Price_']=Price8
df8['Date']='15/1/2023'
# Out:
# 58
# 58
# 58
# 58
# 58
# 58
# 58

# %%
Data4 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8],axis = 0)

# %%
Data4
# Out:
#       Flight DepartureTime ArivalTime     source Destination  \
# 0    AirAsia         04:55      13:05  New Delhi      Mumbai
# 1     IndiGo         06:30      08:45  New Delhi      Mumbai
# 2     IndiGo         16:25      18:40  New Delhi      Mumbai
# 3   SpiceJet         07:00      09:15  New Delhi      Mumbai
# 4   SpiceJet         20:00      22:05  New Delhi      Mumbai
# ..       ...           ...        ...        ...         ...
# 53   Vistara         17:45      19:55  New Delhi      Mumbai
# 54    IndiGo         06:10      12:20  New Delhi      Mumbai
# 55   Vistara         12:50      15:00  New Delhi      Mumbai
# 56   Vistara         19:00      21:15  New Delhi      Mumbai
# 57    IndiGo         10:20      14:55  New Delhi      Mumbai
#
#                          Duration   Price_       Date
# 0    08 h 10 m\n1 stop via Jaipur  ₹ 5,383   8/1/2023
# 1             02 h 15 m\nNon stop  ₹ 5,794   8/1/2023
# 2             02 h 15 m\nNon stop  ₹ 5,794   8/1/2023
# ...

# %%
search_flight = driver.find_element(By.XPATH,'//div[@class="hsw_inputBox width160"][2]/input')
search_flight.send_keys("Hyderabad")

# %%
First_click = driver.find_element(By.XPATH,'//li[@class="react-autosuggest__suggestion react-autosuggest__suggestion--first"]')
First_click.click()

# %%
date_click = driver.find_element(By.XPATH,'//div[@class="DayPicker-Day"][1]')
date_click.click()

# %%
search = driver.find_element(By.XPATH,'//button[@class="primaryBtn hsw_searchButton"]')
search.click()

# %%
flight_name1 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name1.append(i.text)
print(len(flight_name1))

dept_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time1.append(i.text)
print(len(dept_time1))

arive_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time1.append(i.text)
print(len(arive_time1))

Source1 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source1.append(i.text)
print(len(Source1))

Destination1 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination1.append(i.text)
print(len(Destination1))

Duration1 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration1.append(i.text)
print(len(Duration1))

Price1 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price1.append(i.text)
print(len(Price1))

df1 = pd.DataFrame()
df1['Flight'] = flight_name1
df1['DepartureTime'] = dept_time1
df1['ArivalTime']=arive_time1
df1['source']=Source1
df1['Destination']=Destination1
df1['Duration']=Duration1
df1['Price_']=Price1
df1['Date']='8/1/2023'
# Out:
# 24
# 24
# 24
# 24
# 24
# 24
# 24

# %%
Date2 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-2"]')
Date2.click()

# %%
flight_name2 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name2.append(i.text)
print(len(flight_name2))

dept_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time2.append(i.text)
print(len(dept_time2))

arive_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time2.append(i.text)
print(len(arive_time2))

Source2 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source2.append(i.text)
print(len(Source2))

Destination2 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination2.append(i.text)
print(len(Destination2))

Duration2 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration2.append(i.text)
print(len(Duration2))

Price2 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price2.append(i.text)
print(len(Price2))

df2 = pd.DataFrame()
df2['Flight'] = flight_name2
df2['DepartureTime'] = dept_time2
df2['ArivalTime']=arive_time2
df2['source']=Source2
df2['Destination']=Destination2
df2['Duration']=Duration2
df2['Price_']=Price2
df2['Date']='9/1/2023'
# Out:
# 26
# 26
# 26
# 26
# 26
# 26
# 26

# %%
Date3 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-1"]')
Date3.click()

# %%
flight_name3 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name3.append(i.text)
print(len(flight_name3))

dept_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time3.append(i.text)
print(len(dept_time3))

arive_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time3.append(i.text)
print(len(arive_time3))

Source3 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source3.append(i.text)
print(len(Source3))

Destination3 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination3.append(i.text)
print(len(Destination3))

Duration3 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration3.append(i.text)
print(len(Duration3))

Price3 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price3.append(i.text)
print(len(Price3))

df3 = pd.DataFrame()
df3['Flight'] = flight_name3
df3['DepartureTime'] = dept_time3
df3['ArivalTime']=arive_time3
df3['source']=Source3
df3['Destination']=Destination3
df3['Duration']=Duration3
df3['Price_']=Price3
df3['Date']='10/1/2023'
# Out:
# 22
# 22
# 22
# 22
# 22
# 22
# 22

# %%
Date4 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"][1]')
Date4.click()

# %%
flight_name4 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name4.append(i.text)
print(len(flight_name4))

dept_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time4.append(i.text)
print(len(dept_time4))

arive_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time4.append(i.text)
print(len(arive_time4))

Source4 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source4.append(i.text)
print(len(Source4))

Destination4 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination4.append(i.text)
print(len(Destination4))

Duration4 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration4.append(i.text)
print(len(Duration4))

Price4 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price4.append(i.text)
print(len(Price4))

df4 = pd.DataFrame()
df4['Flight'] = flight_name4
df4['DepartureTime'] = dept_time4
df4['ArivalTime']=arive_time4
df4['source']=Source4
df4['Destination']=Destination4
df4['Duration']=Duration4
df4['Price_']=Price4
df4['Date']='11/1/2023'
# Out:
# 32
# 32
# 32
# 32
# 32
# 32
# 32

# %%
Date5 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"]')
Date5.click()

# %%
flight_name5 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name5.append(i.text)
print(len(flight_name5))

dept_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time5.append(i.text)
print(len(dept_time5))

arive_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time5.append(i.text)
print(len(arive_time5))

Source5 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source5.append(i.text)
print(len(Source5))

Destination5 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination5.append(i.text)
print(len(Destination5))

Duration5 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration5.append(i.text)
print(len(Duration5))

Price5 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price5.append(i.text)
print(len(Price5))

df5 = pd.DataFrame()
df5['Flight'] = flight_name5
df5['DepartureTime'] = dept_time5
df5['ArivalTime']=arive_time5
df5['source']=Source5
df5['Destination']=Destination5
df5['Duration']=Duration5
df5['Price_']=Price5
df5['Date']='12/1/2023'
# Out:
# 24
# 24
# 24
# 24
# 24
# 24
# 24

# %%
Date6 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-1"]')
Date6.click()

# %%
flight_name6 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name6.append(i.text)
print(len(flight_name6))

dept_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time6.append(i.text)
print(len(dept_time6))

arive_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time6.append(i.text)
print(len(arive_time6))

Source6 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source6.append(i.text)
print(len(Source6))

Destination6 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination6.append(i.text)
print(len(Destination6))

Duration6 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration6.append(i.text)
print(len(Duration6))

Price6 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price6.append(i.text)
print(len(Price6))

df6 = pd.DataFrame()
df6['Flight'] = flight_name6
df6['DepartureTime'] = dept_time6
df6['ArivalTime']=arive_time6
df6['source']=Source6
df6['Destination']=Destination6
df6['Duration']=Duration6
df6['Price_']=Price6
df6['Date']='13/1/2023'
# Out:
# 23
# 23
# 23
# 23
# 23
# 23
# 23

# %%
Date7 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-2"]')
Date7.click()

# %%
flight_name7 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name7.append(i.text)
print(len(flight_name7))

dept_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time7.append(i.text)
print(len(dept_time7))

arive_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time7.append(i.text)
print(len(arive_time7))

Source7 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source7.append(i.text)
print(len(Source7))

Destination7 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination7.append(i.text)
print(len(Destination7))

Duration7 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration7.append(i.text)
print(len(Duration7))

Price7=[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price7.append(i.text)
print(len(Price7))

df7 = pd.DataFrame()
df7['Flight'] = flight_name7
df7['DepartureTime'] = dept_time7
df7['ArivalTime']=arive_time7
df7['source']=Source7
df7['Destination']=Destination7
df7['Duration']=Duration7
df7['Price_']=Price7
df7['Date']='14/1/2023'
# Out:
# 23
# 23
# 23
# 23
# 23
# 23
# 23

# %%
button = driver.find_element(By.XPATH,'//button[@class="glider-next"][1]')
button.click()

# %%
Date8 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide active visible left-4"]')
Date8.click()

# %%
flight_name8 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name8.append(i.text)
print(len(flight_name8))

dept_time8 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time8.append(i.text)
print(len(dept_time8))

arive_time8 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time8.append(i.text)
print(len(arive_time8))

Source8 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source8.append(i.text)
print(len(Source8))

Destination8 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination8.append(i.text)
print(len(Destination8))

Duration8 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration8.append(i.text)
print(len(Duration8))

Price8=[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price8.append(i.text)
print(len(Price8))

df8 = pd.DataFrame()
df8['Flight'] = flight_name8
df8['DepartureTime'] = dept_time8
df8['ArivalTime']=arive_time8
df8['source']=Source8
df8['Destination']=Destination8
df8['Duration']=Duration8
df8['Price_']=Price8
df8['Date']='15/1/2023'
# Out:
# 21
# 21
# 21
# 21
# 21
# 21
# 21

# %%
Data5 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8],axis = 0)

# %%
Data5.head()
# Out:
#       Flight DepartureTime ArivalTime     source Destination  \
# 0   SpiceJet         16:25      18:45  New Delhi   Hyderabad
# 1     IndiGo         06:30      08:50  New Delhi   Hyderabad
# 2  Air India         07:10      09:20  New Delhi   Hyderabad
# 3    Vistara         07:20      09:25  New Delhi   Hyderabad
# 4     IndiGo         08:10      10:30  New Delhi   Hyderabad
#
#               Duration   Price_      Date
# 0  02 h 20 m\nNon stop  ₹ 5,182  8/1/2023
# 1  02 h 20 m\nNon stop  ₹ 5,184  8/1/2023
# 2  02 h 10 m\nNon stop  ₹ 5,184  8/1/2023
# 3  02 h 05 m\nNon stop  ₹ 5,184  8/1/2023
# 4  02 h 20 m\nNon stop  ₹ 5,184  8/1/2023

# %%
search_flight = driver.find_element(By.XPATH,'//div[@class="hsw_inputBox width160"][2]/input')
search_flight.send_keys("Kochi")

# %%
First_click = driver.find_element(By.XPATH,'//li[@class="react-autosuggest__suggestion react-autosuggest__suggestion--first"]')
First_click.click()

# %%
date_click = driver.find_element(By.XPATH,'//div[@class="DayPicker-Day"][1]')
date_click.click()

# %%
search = driver.find_element(By.XPATH,'//button[@class="primaryBtn hsw_searchButton"]')
search.click()

# %%
flight_name1 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name1.append(i.text)
print(len(flight_name1))

dept_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time1.append(i.text)
print(len(dept_time1))

arive_time1 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time1.append(i.text)
print(len(arive_time1))

Source1 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source1.append(i.text)
print(len(Source1))

Destination1 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination1.append(i.text)
print(len(Destination1))

Duration1 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration1.append(i.text)
print(len(Duration1))

Price1 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price1.append(i.text)
print(len(Price1))

df1 = pd.DataFrame()
df1['Flight'] = flight_name1
df1['DepartureTime'] = dept_time1
df1['ArivalTime']=arive_time1
df1['source']=Source1
df1['Destination']=Destination1
df1['Duration']=Duration1
df1['Price_']=Price1
df1['Date']='8/1/2023'
# Out:
# 39
# 39
# 39
# 39
# 39
# 39
# 39

# %%
Date2 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-2"]')
Date2.click()

# %%
flight_name2 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name2.append(i.text)
print(len(flight_name2))

dept_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time2.append(i.text)
print(len(dept_time2))

arive_time2 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time2.append(i.text)
print(len(arive_time2))

Source2 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source2.append(i.text)
print(len(Source2))

Destination2 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination2.append(i.text)
print(len(Destination2))

Duration2 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration2.append(i.text)
print(len(Duration2))

Price2 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price2.append(i.text)
print(len(Price2))

df2 = pd.DataFrame()
df2['Flight'] = flight_name2
df2['DepartureTime'] = dept_time2
df2['ArivalTime']=arive_time2
df2['source']=Source2
df2['Destination']=Destination2
df2['Duration']=Duration2
df2['Price_']=Price2
df2['Date']='9/1/2023'
# Out:
# 40
# 40
# 40
# 40
# 40
# 40
# 40

# %%
Date3 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible left-1"]')
Date3.click()

# %%
flight_name3 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name3.append(i.text)
print(len(flight_name3))

dept_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time3.append(i.text)
print(len(dept_time3))

arive_time3 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time3.append(i.text)
print(len(arive_time3))

Source3 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source3.append(i.text)
print(len(Source3))

Destination3 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination3.append(i.text)
print(len(Destination3))

Duration3 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration3.append(i.text)
print(len(Duration3))

Price3 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price3.append(i.text)
print(len(Price3))

df3 = pd.DataFrame()
df3['Flight'] = flight_name3
df3['DepartureTime'] = dept_time3
df3['ArivalTime']=arive_time3
df3['source']=Source3
df3['Destination']=Destination3
df3['Duration']=Duration3
df3['Price_']=Price3
df3['Date']='10/1/2023'
# Out:
# 40
# 40
# 40
# 40
# 40
# 40
# 40

# %%
Date4 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"][1]')
Date4.click()

# %%
flight_name4 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name4.append(i.text)
print(len(flight_name4))

dept_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time4.append(i.text)
print(len(dept_time4))

arive_time4 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time4.append(i.text)
print(len(arive_time4))

Source4 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source4.append(i.text)
print(len(Source4))

Destination4 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination4.append(i.text)
print(len(Destination4))

Duration4 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration4.append(i.text)
print(len(Duration4))

Price4 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price4.append(i.text)
print(len(Price4))

df4 = pd.DataFrame()
df4['Flight'] = flight_name4
df4['DepartureTime'] = dept_time4
df4['ArivalTime']=arive_time4
df4['source']=Source4
df4['Destination']=Destination4
df4['Duration']=Duration4
df4['Price_']=Price4
df4['Date']='11/1/2023'
# Out:
# 40
# 40
# 40
# 40
# 40
# 40
# 40

# %%
Date5 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide center visible"]')
Date5.click()

# %%
flight_name5 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name5.append(i.text)
print(len(flight_name5))

dept_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:200:2]:
    dept_time5.append(i.text)
print(len(dept_time5))

arive_time5 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:200:2]:
    arive_time5.append(i.text)
print(len(arive_time5))

Source5 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:200:2]:
    Source5.append(i.text)
print(len(Source5))

Destination5 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:200:2]:
    Destination5.append(i.text)
print(len(Destination5))

Duration5 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration5.append(i.text)
print(len(Duration5))

Price5 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price5.append(i.text)
print(len(Price5))

df5 = pd.DataFrame()
df5['Flight'] = flight_name5
df5['DepartureTime'] = dept_time5
df5['ArivalTime']=arive_time5
df5['source']=Source5
df5['Destination']=Destination5
df5['Duration']=Duration5
df5['Price_']=Price5
df5['Date']='12/1/2023'
# Out:
# 84
# 84
# 84
# 84
# 84
# 84
# 84

# %%
Date6 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-1"]')
Date6.click()

# %%
flight_name6 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name6.append(i.text)
print(len(flight_name6))

dept_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time6.append(i.text)
print(len(dept_time6))

arive_time6 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time6.append(i.text)
print(len(arive_time6))

Source6 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source6.append(i.text)
print(len(Source6))

Destination6 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination6.append(i.text)
print(len(Destination6))

Duration6 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration6.append(i.text)
print(len(Duration6))

Price6 =[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price6.append(i.text)
print(len(Price6))

df6 = pd.DataFrame()
df6['Flight'] = flight_name6
df6['DepartureTime'] = dept_time6
df6['ArivalTime']=arive_time6
df6['source']=Source6
df6['Destination']=Destination6
df6['Duration']=Duration6
df6['Price_']=Price6
df6['Date']='13/1/2023'
# Out:
# 39
# 39
# 39
# 39
# 39
# 39
# 39

# %%
Date7 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-2"]')
Date7.click()

# %%
flight_name7 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name7.append(i.text)
print(len(flight_name7))

dept_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time7.append(i.text)
print(len(dept_time7))

arive_time7 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time7.append(i.text)
print(len(arive_time7))

Source7 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source7.append(i.text)
print(len(Source7))

Destination7 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination7.append(i.text)
print(len(Destination7))

Duration7 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration7.append(i.text)
print(len(Duration7))

Price7=[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price7.append(i.text)
print(len(Price7))

df7 = pd.DataFrame()
df7['Flight'] = flight_name7
df7['DepartureTime'] = dept_time7
df7['ArivalTime']=arive_time7
df7['source']=Source7
df7['Destination']=Destination7
df7['Duration']=Duration7
df7['Price_']=Price7
df7['Date']='14/1/2023'
# Out:
# 39
# 39
# 39
# 39
# 39
# 39
# 39

# %%
button = driver.find_element(By.XPATH,'//button[@class="glider-next"][1]')
button.click()

# %%
Date8 = driver.find_element(By.XPATH,'//div[@class="weeklyFareItems glider-slide visible right-2"]')
Date8.click()

# %%
flight_name8 =[]
Name = driver.find_elements(By.XPATH,'//p[@class="boldFont blackText airlineName"]')
for i in Name:
    flight_name8.append(i.text)
print(len(flight_name8))

dept_time8 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[0:107:2]:
    dept_time8.append(i.text)
print(len(dept_time8))

arive_time8 =[]
t = driver.find_elements(By.XPATH,'//p[@class="appendBottom2 flightTimeInfo"]')
for i in t[1:107:2]:
    arive_time8.append(i.text)
print(len(arive_time8))

Source8 =[]
s = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in s[0:107:2]:
    Source8.append(i.text)
print(len(Source8))

Destination8 =[]
d = driver.find_elements(By.XPATH,'//p[@class="blackText"]')
for i in d[1:107:2]:
    Destination8.append(i.text)
print(len(Destination8))

Duration8 =[]
d = driver.find_elements(By.XPATH,'//div[@class="stop-info flexOne"]')
for i in d:
    Duration8.append(i.text)
print(len(Duration8))

Price8=[]
p = driver.find_elements(By.XPATH,'//p[@class="blackText fontSize18 blackFont white-space-no-wrap"]')
for i in p:
    Price8.append(i.text)
print(len(Price8))

df8 = pd.DataFrame()
df8['Flight'] = flight_name8
df8['DepartureTime'] = dept_time8
df8['ArivalTime']=arive_time8
df8['source']=Source8
df8['Destination']=Destination8
df8['Duration']=Duration8
df8['Price_']=Price8
df8['Date']='15/1/2023'
# Out:
# 12
# 12
# 12
# 12
# 12
# 12
# 12

# %%
Data6 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8],axis = 0)

# %%
final = pd.concat([Data1,Data2,Data3,Data4,Data5,Data6],axis =0)

# %%
final
# Out:
#        Flight DepartureTime ArivalTime     source Destination  \
# 0    SpiceJet         06:20      09:10  New Delhi   Bengaluru
# 1     AirAsia         08:10      10:55  New Delhi   Bengaluru
# 2      IndiGo         07:55      10:55  New Delhi   Bengaluru
# 3      IndiGo         04:20      07:15  New Delhi   Bengaluru
# 4      IndiGo         05:55      08:45  New Delhi   Bengaluru
# ..        ...           ...        ...        ...         ...
# 7   Air India         04:55      08:00  New Delhi       Kochi
# 8   Air India         16:45      20:10  New Delhi       Kochi
# 9    Go First         14:35      19:25  New Delhi       Kochi
# 10     IndiGo         05:25      08:45  New Delhi       Kochi
# 11    AirAsia         06:05      09:15  New Delhi       Kochi
#
#                         Duration    Price_       Date
# 0            02 h 50 m\nNon stop   ₹ 5,234   8/1/2023
# 1            02 h 45 m\nNon stop   ₹ 5,235   8/1/2023
# 2                 03 h\nNon stop   ₹ 4,537   8/1/2023
# ...

# %%
final.to_csv('flight_data.csv')

# %%
df = pd.read_csv('flight_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    Flight DepartureTime ArivalTime     source Destination  \
# 0           0  SpiceJet         06:20      09:10  New Delhi   Bengaluru
# 1           1   AirAsia         08:10      10:55  New Delhi   Bengaluru
# 2           2    IndiGo         07:55      10:55  New Delhi   Bengaluru
# 3           3    IndiGo         04:20      07:15  New Delhi   Bengaluru
# 4           4    IndiGo         05:55      08:45  New Delhi   Bengaluru
#
#               Duration   Price_      Date
# 0  02 h 50 m\nNon stop  ₹ 5,234  8/1/2023
# 1  02 h 45 m\nNon stop  ₹ 5,235  8/1/2023
# 2       03 h\nNon stop  ₹ 4,537  8/1/2023
# 3  02 h 55 m\nNon stop  ₹ 5,237  8/1/2023
# 4  02 h 50 m\nNon stop  ₹ 5,237  8/1/2023

# %%
df['DepartureTime'].unique()
# Out:
# array(['06:20', '08:10', '07:55', '04:20', '05:55', '07:00', '09:15',
#        '10:40', '12:15', '13:05', '13:15', '08:00', '09:05', '09:20',
#        '20:30', '05:45', '09:45', '13:30', '17:00', '21:10', '14:00',
#        '21:45', '21:20', '15:05', '20:10', '19:20', '09:30', '05:35',
#        '06:10', '19:25', '11:50', '22:55', '01:55', '16:30', '15:35',
#        '19:55', '20:40', '17:25', '07:10', '19:05', '09:00', '17:30',
#        '10:45', '15:40', '16:05', '14:10', '16:55', '16:50', '07:20',
#        '10:55', '05:50', '08:20', '15:10', '14:35', '06:30', '16:10',
#        '17:35', '10:10', '17:15', '19:45', '17:55', '19:50', '16:45',
#        '17:45', '13:40', '23:05', '18:50', '08:25', '12:10', '07:40',
#        '19:40', '10:30', '15:55', '23:50', '12:45', '06:15', '18:15',
#        '22:30', '20:00', '02:40', '12:20', '14:50', '21:00', '08:30',
#        '20:35', '03:00', '04:35', '22:50', '23:55', '07:30', '13:55',
# ...

# %%
df['Flight'].unique()
# Out:
# array(['SpiceJet', 'AirAsia', 'IndiGo', 'Air India', 'Vistara',
#        'Go First', 'Akasa Air', 'Air India, AirAsia', 'Vistara, IndiGo',
#        'Air India, Akasa Air', 'IndiGo, AirAsia', 'Vistara, Akasa Air',
#        'SpiceJet, Go First', 'SpiceJet, Akasa Air', 'Air India, IndiGo',
#        'IndiGo, Akasa Air', 'IndiGo, Air India', 'Go First, Akasa Air',
#        'AirAsia, Akasa Air', 'SpiceJet, Air India', 'AirAsia, IndiGo',
#        'Alliance Air, IndiGo', 'SpiceJet, IndiGo',
#        'Air India, Alliance Air', 'IndiGo, Go First',
#        'SpiceJet, Alliance Air', 'AirAsia, Alliance Air',
#        'IndiGo, Alliance Air', 'Go First, AirAsia', 'AirAsia, Go First',
#        'Vistara, AirAsia', 'Akasa Air, Alliance Air',
#        'Akasa Air, Go First', 'SpiceJet, AirAsia'], dtype=object)

# %%
df['Destination'].unique()
# Out:
# array(['Bengaluru', 'Chennai', 'Kolkata', 'Mumbai', 'Hyderabad', 'Kochi'],
#       dtype=object)
